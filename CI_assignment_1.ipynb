# %% [markdown]
# $\Huge Computational$ $\Huge Intelligence$ $\Huge Lab$
#
# $\Huge  Assignment$ $\Huge 1$
# ---
# Fill in your name, surname and group...
# ---

# %% [markdown]
# # 1.1 Function
# Consider the following Python class.

# %%
import numpy as np

class Function:
  def __init__(self,n_h,activation=lambda x : x):
    self.f=activation
    self.W0=np.random.randn(n_h,1)*np.sqrt(1/n_h)
    self.b0=np.zeros((n_h,1))
    self.W1=np.random.randn(1,n_h)*np.sqrt(1/n_h)
    self.b1=np.zeros((1,1))

  def __call__(self,x):
    z=self.W0*x+self.b0
    a  = self.f(z)
    y=np.dot(self.W1,a)+self.b1
    return y[0]

x=np.linspace(0,10,100)
f=Function(4)
y=f(x)

# %% [markdown]
# Operations placed in the function call operator can be expressed as:
#
#
# *   $z = W_0\cdot x+b_0$
# *   $a = f(z)$
# *   $y = W_1*a+b_1$
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **TODO 1.1.1** Create function objects for various values of ```n_h``` and display their shapes. Use a for loop

# %%
import matplotlib.pyplot as plt
for i in range(10):
  plt.plot(x, Function(5+3**i)(x))

# %% [markdown]
# Run the following code.
#
# **Question: What are the shapes of function graphs? Why there are multiple plots?**

# %%
import matplotlib.pyplot as plt
for i in range(10):
  plt.plot(x,Function(5)(x))

# %% [markdown]
# **TODO 1.1.2** Define two functions:
#
# *   $sigmoid(x)=\frac{1}{1+exp(-x)}$
# *   $rbf(x)=exp(-x^2)$

# %%
def sigmoid(z):
  return(1/(1+np.exp(-z*0.5)))

def rbf(z):
  return(np.exp(-z**2))

# %% [markdown]
# then plot their graphs

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)

plt.plot(x,sigmoid(x),c='r',label='sigmoid')
plt.plot(x,rbf(x),c='b',label='rbf')
plt.legend()

# %% [markdown]
# **TODO 1.1.3** Display several function plots for activation = sigmoid

# %%
import matplotlib.pyplot as plt
x=np.linspace(0,10,100)
for i in range(10):
  plt.plot(x,Function(5, activation = sigmoid)(x))

# %% [markdown]
# **TODO 1.1.4** Display several function plots for activation = rbf

# %%
x=np.linspace(0,10,100)
for i in range(10):
  plt.plot(x,Function(5, activation = rbf)(x))

# %% [markdown]
# # 1.2 Implementation based on TensorFlow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
import tensorflow as tf


class Function:
  def __init__(self,n_h,activation = lambda x:x):
    self.f = activation
    self.W0=tf.Variable(np.random.randn(n_h,1)*np.sqrt(1/n_h))
    self.b0=tf.Variable(np.zeros((n_h,1)))
    self.W1=tf.Variable(np.random.randn(1,n_h)*np.sqrt(1/n_h))
    self.b1=tf.Variable(np.zeros((1,1)))


  def __call__(self,x):
    z=self.W0*x+self.b0
    a=sigmoid(z)
    y=tf.matmul(self.W1,a)+self.b1
    return y

# %% [markdown]
# Run the cell below several times. Each time the function shape changes.

# %%
x=np.linspace(0,10,100)
f=Function(10, activation = sigmoid)
y=f(x)
plt.plot(x,y.numpy()[0])

# %% [markdown]
# ## How to fit the model to a given function?
#
# We need
# 1.   A measure to evaluate model fitness
# 2.   A loss function to find the optimal model
# 3.   Loss function may be identical to measure (but does not have to)
# 4. An optimization procedure that minimizes the loss

# %% [markdown]
# **TODO 1.2.1** Analyze the code in the cell below and complete the code of MSE function. MSE means Mean Squared Error

# %%
a = tf.Variable([1.0,2.0,3.0,4.0])
b = tf.Variable([1.1,2.1,3.1,4.1])
e = (a-b)**2
print(e)
mse=tf.math.reduce_sum(e)/e.shape[0]
print(mse)
# Out:
# tf.Tensor([0.01       0.00999998 0.00999998 0.00999998], shape=(4,), dtype=float32)
# tf.Tensor(0.009999987, shape=(), dtype=float32)

# %%
def MSE(y_true,y_pred):
  e = (y_true - y_pred)**2
  return tf.math.reduce_sum(e)/e.shape[0]

MSE(a,b)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.009999987>

# %% [markdown]
# **TODO 1.2.2** Rewrite sigmoid and rbf functions using  TensorFlow

# %%
def sigmoid(x):
  return 1 / (1+tf.exp(-x))

def rbf(x):
  return tf.exp(-x**2)

# %% [markdown]
# ## The fit method
#
# * Input: x and y
# * Iterates multiple times (parameter epoch)
# * In each iteration
#   * Calculates y_pred = model(x)
#   * Computes loss function
#   * Computes gradient of loss function with respect to weights
#   * Updates weights, basicaly according to the formula $W=W-gradient*learning\_rate$.
#   * Actually uses an optimizer that performs this in a smarter way

# %%
import tensorflow as tf


class Function:
  def __init__(self,n_h,activation = lambda x:x):
    self.f = activation
    self.W0=tf.Variable(np.random.randn(n_h,1)*0.01)
    self.b0=tf.Variable(np.zeros((n_h,1)))
    self.W1=tf.Variable(np.random.randn(1,n_h)*0.01)
    self.b1=tf.Variable(np.zeros((1,1)))


  def __call__(self,x):
    z=self.W0*x+self.b0
    a=self.f(z)
    y=tf.matmul(self.W1,a)+self.b1
    return y


  def fit(self,x,y,epochs=10,optimizer = tf.keras.optimizers.RMSprop()):
    for i in range(epochs):
      with tf.GradientTape() as tape:
        y_pred=self(x)
        loss = MSE(y_pred,y)
        # print(loss)
        variables=(self.W0,self.b0,self.W1,self.b1)
        gradients = tape.gradient(loss, variables)
        # print(gradients)
        optimizer.apply_gradients(zip(gradients, variables))

# %% [markdown]
# We will try to fit our model (Function class) to the polynomial function $y=(x-1)(x-6)(x-7)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)

plt.plot(x,y)
plt.grid()

# %% [markdown]
# Although the problem is super-easy for classical methods, using this approach is a little bit hard. We need many hidden units and iterations... (execution abot 90 sec)
#
# **TODO 1.2.3** Create a model (Function) object passing as parameters 50 hidden units and rbf activation function. Fit the model setting number of iterations to 5000.

# %%
f=Function(n_h = 50, activation = rbf)
f.fit(x,y,epochs = 5000)

plt.plot(x,y)
plt.grid()

y_pred=f(x)
plt.plot(x,y_pred.numpy()[0])

# %% [markdown]
# **Hyperparameters**
# *  n_h (number of hidden neurons) controls the model complexity
# *  activation function - influences the model performance
# *  epochs - controls number of iterations (influences the learning algorithm)

# %% [markdown]
# # 1.3 Neural network model
#
# Analogous model can be built using components of keras library.
#
# *  **Advantage** the computations are converted to form a *computational graph* that can be executed much faster. Also on GPU. This is done with ```compile``` method.

# %%
from keras import models
from keras import layers

def build_model(n_h):
  model = models.Sequential()
  model.add(layers.Dense(n_h, activation=rbf, input_shape=(1,)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mse','mae'])
  return model

# %% [markdown]
# **TODO 1.3.1** Create a model with 50 hidden units and call fit function setting number of epochs 5000 and batch_size (another hyperparameter) to 100

# %%
import numpy as np
x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)

model = build_model(50)
model.summary()
history = model.fit(x,y, epochs=10000, batch_size = 100, verbose = 0)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                100
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 151 (604.00 Byte)
# Trainable params: 151 (604.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Check plots of original and fit curves

# %%
plt.plot(x,y)
plt.grid()

y_pred=model.predict(x)
plt.plot(x,y_pred)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# **TODO 1.3.2** Repat the above steps changing hyperparameters to get a good fit

# %% [markdown]
# During training some data are collected. We may display various measures residing in the training history

# %%
import matplotlib.pyplot as plt

plt.title('Training history - MSE')
plt.plot(history.history['mse'],label='mse')
plt.xlabel('iteration')
plt.ylabel('MSE')
plt.legend()

# history.history['mse']

# %% [markdown]
# # 1.4 More realsitic model
# The task of perfectly fitting a known function is very rare.
#
# *  It is rather assumed that we have data that originate from a true underlaying function with a noise $y=f(x)+\varepsilon$
# *  It is also often assumed that $\varepsilon \sim N(0,\sigma)$

# %%
from keras import models
from keras import layers
import numpy as np
import matplotlib.pyplot as plt

n_size=100
x = np.linspace(0,10,n_size)
y = (x-1)*(x-6)*(x-7)+np.random.normal(0,10,n_size)

plt.scatter(x,y)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')

# %% [markdown]
# **TODO 1.4.1** Fit the model to this DATA using the best hyperparameters obtained before

# %%
model = build_model(50)
history = model.fit(x,y, epochs=10000, batch_size = 100, verbose = 0)

# %% [markdown]
# **TODO 1.4.2** Plot the scattered data, true function in green and predictions in red

# %%
plt.scatter(x,y)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')
y_pred=model.predict(x)
plt.plot(x,y_pred,color='r')
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# # 1.5 Validating model - training and testing
#
# Typical ML workflow includes training the model and testing its performance on unseen data.
#
# * **Why** - to control and assess generalization error which may result from
#     * underfitting - the model is to simple or not trained enough
#     * overfitting - the model is too complex, matches perfectly the training data (see part of the plot on the left)

# %% [markdown]
# We will split the data into two subsets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=123)

# %% [markdown]
# **TODO 1.5.1** Fit the model using x_train and y_train, set the parameter ```validation_data=(x_test, y_test)```
#
# Warning: training lasts up to 250 sec

# %%
model = build_model(50)
history = model.fit(x,y, epochs=10000, batch_size = x_train.shape[0], verbose = 0, validation_data = (x_test, y_test))

# %% [markdown]
# We will display true function, noisy data and predictions

# %%
plt.scatter(x_test,y_test)
plt.plot(x,(x-1)*(x-6)*(x-7),color='g')
y_pred=model.predict(x_test)
plt.scatter(x_test,y_pred,color='r')
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %% [markdown]
# Lets peek what is the content of the history...

# %%
for k in history.history:
  print(k)
# Out:
# loss
# mse
# mae
# val_loss
# val_mse
# val_mae

# %% [markdown]
# **TODO 1.5.2** Display loss (training loss) and val_loss (validation loss on the test set)

# %%
plt.plot(history.history["loss"] , label='train loss')
plt.plot(history.history["val_loss"] , label='validation loss')
plt.legend()

# %% [markdown]
# # 1.6 Classification
# Function models can be used for classification, provided we constrain them to return probabilities, i.e.  values from [0,1] interval.
#
# * Function with one output may be used for binary classification:
#   *  Assign $label_0$ if $f(x) <0.5$
#   *  Assign $label_1$ if $f(x) \ge 0.5$
#
# **TODO 1.6.1**Which function converts $R \to [0,1]$? Answer the question

# %%
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)

plt.plot(x,(lambda x: 1/(1+np.exp(-x)))(x),c='r')

# %% [markdown]
# We will generate a dataset. Points above the previously used polynomial will have blue label, the points below red.

# %%
X = np.random.rand(1000,2)*[10,150]-[0,40]
y = np.where(X[:,1]>(X[:,0]-1)*(X[:,0]-6)*(X[:,0]-7),1,0)
# y.shape

from matplotlib.colors import ListedColormap
cm = ListedColormap(['r', 'b'])
plt.scatter(X[:,0],X[:,1],c=y,cmap=cm)

# %% [markdown]
# We will biuld a model more suitable for classification.
#
# What is binary_crossentropy aka. logloss?
#
# $loss_i= -[ y_i\cdot ln(p_i) + (1-y_i)\cdot ln(1-p_i)]$
#
# You may google the term...

# %%
import tensorflow as tf


def build_classification_model(n_h):
  model = models.Sequential()
  model.add(layers.Dense(n_h, activation='relu', input_shape=(2,)))
  model.add(layers.Dense(n_h, activation='relu'))
  model.add(layers.Dense(1,activation='sigmoid'))
  model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
  return model

# %% [markdown]
# **TODO 1.6.2** fit the model using training data. Set about 100 epochs, use X_test and y_test as validation data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

model = build_classification_model(10)
history = model.fit(X_train,y_train, epochs=1000, batch_size = 100, verbose = 1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 30ms/step - loss: 1.2053 - accuracy: 0.6286 - val_loss: 0.9684 - val_accuracy: 0.6033
# Epoch 2/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7635 - accuracy: 0.6371 - val_loss: 0.7093 - val_accuracy: 0.6467
# Epoch 3/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5686 - accuracy: 0.6886 - val_loss: 0.5595 - val_accuracy: 0.7000
# Epoch 4/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4559 - accuracy: 0.7714 - val_loss: 0.4683 - val_accuracy: 0.7467
# Epoch 5/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3868 - accuracy: 0.8371 - val_loss: 0.4134 - val_accuracy: 0.8200
# Epoch 6/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3458 - accuracy: 0.8743 - val_loss: 0.3721 - val_accuracy: 0.8633
# Epoch 7/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3239 - accuracy: 0.8843 - val_loss: 0.3460 - val_accuracy: 0.8667
# Epoch 8/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3058 - accuracy: 0.8900 - val_loss: 0.3241 - val_accuracy: 0.8867
# Epoch 9/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2960 - accuracy: 0.8929 - val_loss: 0.3137 - val_accuracy: 0.8867
# Epoch 10/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.
1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2150 - accuracy: 0.9057 - val_loss: 0.2360 - val_accuracy: 0.8800
# Epoch 101/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2153 - accuracy: 0.9029 - val_loss: 0.2278 - val_accuracy: 0.8700
# Epoch 102/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2158 - accuracy: 0.8943 - val_loss: 0.2275 - val_accuracy: 0.8700
# Epoch 103/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2116 - accuracy: 0.9071 - val_loss: 0.2276 - val_accuracy: 0.8700
# Epoch 104/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9071 - val_loss: 0.2279 - val_accuracy: 0.8700
# Epoch 105/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2122 - accuracy: 0.9043 - val_loss: 0.2280 - val_accuracy: 0.8733
# Epoch 106/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2110 - accuracy: 0.9014 - val_loss: 0.2271 - val_accuracy: 0.8700
# Epoch 107/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2177 - accuracy: 0.9043 - val_loss: 0.2308 - val_accuracy: 0.8800
# Epoch 108/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2106 - accuracy: 0.9014 - val_loss: 0.2286 - val_accuracy: 0.8767
# Epoch 109/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2118 - accuracy: 0.9029 - val_loss: 0.2309 - val_accuracy: 0.8800
# Epoch 110/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2100 - accuracy: 0.9000 - val_loss: 0.2297 - val_accuracy: 0.8800
# Epoch 111/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2156 - accuracy: 0.9029 - val_loss: 0.2276 - val_accuracy: 0.8733
# Epoch 112/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2114 - accuracy: 0.9029 - val_loss: 0.2305 - val_accuracy: 0.8700
# Epoch 113/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2142 - accuracy: 0.9014 - val_loss: 0.2263 - val_accuracy: 0.8700
# Epoch 114/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2110 - accuracy: 0.9014 - val_loss: 0.2262 - val_accuracy: 0.8700
# Epoch 115/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2108 - accuracy: 0.9057 - val_loss: 0.2258 - val_accuracy: 0.8700
# Epoch 116/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2142 - accuracy: 0.9014 - val_loss: 0.2260 - val_accuracy: 0.8700
# Epoch 117/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2099 - accuracy: 0.9057 - val_loss: 0.2268 - val_accuracy: 0.8733
# Epoch 118/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2134 - accuracy: 0.9029 - val_loss: 0.2266 - val_accuracy: 0.8733
# Epoch 119/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2104 - accuracy: 0.9029 - val_loss: 0.2267 - val_accuracy: 0.8733
# Epoch 120/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2096 - accuracy: 0.9029 - val_loss: 0.2259 - val_accuracy: 0.8700
# Epoch 121/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2107 - accuracy: 0.9000 - val_loss: 0.2283 - val_accuracy: 0.8800
# Epoch 122/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2117 - accuracy: 0.9000 - val_loss: 0.2292 - val_accuracy: 0.8700
# Epoch 123/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2125 - accuracy: 0.9029 - val_loss: 0.2291 - val_accuracy: 0.8800
# Epoch 124/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.2090 - accuracy: 0.8957 - val_loss: 0.2289 - val_accuracy: 0.8800
# Epoch 125/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2112 - accuracy: 0.8971 - val_loss: 0.2259 - val_accuracy: 0.8733
# Epoch 126/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2081 - accuracy: 0.9029 - val_loss: 0.2253 - val_accuracy: 0.8700
# Epoch 127/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2113 - accuracy: 0.9057 - val_loss: 0.2299 - val_accuracy: 0.8800
# Epoch 128/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2066 - accuracy: 0.9029 - val_loss: 0.2259 - val_accuracy: 0.8733
# Epoch 129/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2106 - accuracy: 0.8986 - val_loss: 0.2288 - val_accuracy: 0.8733
# Epoch 130/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.

# 7/7 [==============================] - 0s 13ms/step - loss: 0.1160 - accuracy: 0.9643 - val_loss: 0.1314 - val_accuracy: 0.9400
# Epoch 946/1000
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1121 - accuracy: 0.9643 - val_loss: 0.1341 - val_accuracy: 0.9367
# Epoch 947/1000
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1143 - accuracy: 0.9600 - val_loss: 0.1330 - val_accuracy: 0.9433
# Epoch 948/1000
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1132 - accuracy: 0.9657 - val_loss: 0.1313 - val_accuracy: 0.9467
# Epoch 949/1000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1148 - accuracy: 0.9700 - val_loss: 0.1368 - val_accuracy: 0.9400
# Epoch 950/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1128 - accuracy: 0.9686 - val_loss: 0.1326 - val_accuracy: 0.9400
# Epoch 951/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1143 - accuracy: 0.9600 - val_loss: 0.1327 - val_accuracy: 0.9367
# Epoch 952/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1134 - accuracy: 0.9643 - val_loss: 0.1337 - val_accuracy: 0.9433
# Epoch 953/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1110 - accuracy: 0.9686 - val_loss: 0.1329 - val_accuracy: 0.9433
# Epoch 954/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1177 - accuracy: 0.9614 - val_loss: 0.1347 - val_accuracy: 0.9400
# Epoch 955/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1119 - accuracy: 0.9614 - val_loss: 0.1311 - val_accuracy: 0.9433
# Epoch 956/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1124 - accuracy: 0.9714 - val_loss: 0.1325 - val_accuracy: 0.9400
# Epoch 957/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1109 - accuracy: 0.9686 - val_loss: 0.1315 - val_accuracy: 0.9467
# Epoch 958/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1124 - accuracy: 0.9614 - val_loss: 0.1296 - val_accuracy: 0.9400
# Epoch 959/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1117 - accuracy: 0.9657 - val_loss: 0.1308 - val_accuracy: 0.9433
# Epoch 960/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1127 - accuracy: 0.9671 - val_loss: 0.1328 - val_accuracy: 0.9433
# Epoch 961/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1119 - accuracy: 0.9629 - val_loss: 0.1334 - val_accuracy: 0.9400
# Epoch 962/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1141 - accuracy: 0.9686 - val_loss: 0.1393 - val_accuracy: 0.9367
# Epoch 963/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1080 - accuracy: 0.9657 - val_loss: 0.1300 - val_accuracy: 0.9400
# Epoch 964/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1110 - accuracy: 0.9757 - val_loss: 0.1335 - val_accuracy: 0.9433
# Epoch 965/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1126 - accuracy: 0.9686 - val_loss: 0.1319 - val_accuracy: 0.9433
# Epoch 966/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1162 - accuracy: 0.9657 - val_loss: 0.1309 - val_accuracy: 0.9433
# Epoch 967/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1120 - accuracy: 0.9686 - val_loss: 0.1290 - val_accuracy: 0.9433
# Epoch 968/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1088 - accuracy: 0.9700 - val_loss: 0.1297 - val_accuracy: 0.9400
# Epoch 969/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1081 - accuracy: 0.9643 - val_loss: 0.1297 - val_accuracy: 0.9467
# Epoch 970/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1089 - accuracy: 0.9671 - val_loss: 0.1391 - val_accuracy: 0.9400
# Epoch 971/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1148 - accuracy: 0.9629 - val_loss: 0.1363 - val_accuracy: 0.9400
# Epoch 972/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1101 - accuracy: 0.9686 - val_loss: 0.1289 - val_accuracy: 0.9433
# Epoch 973/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1163 - accuracy: 0.9643 - val_loss: 0.1295 - val_accuracy: 0.9367
# Epoch 974/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1123 - accuracy: 0.9700 - val_loss: 0.1275 - val_accuracy: 0.9433
# Epoch 975/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1111 - accuracy: 0.9643 - val_loss: 0.1362 - val_accuracy: 0.9400
# Epoch 976/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1132 - accuracy: 0.9671 - val_loss: 0.1305 - val_accuracy: 0.9433
# Epoch 977/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1079 - accuracy: 0.9686 - val_loss: 0.1270 - val_accuracy: 0.9433
# Epoch 978/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1116 - accuracy: 0.9614 - val_loss: 0.1283 - val_accuracy: 0.9467
# Epoch 979/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1070 - accuracy: 0.9714 - val_loss: 0.1270 - val_accuracy: 0.9433
# Epoch 980/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1085 - accuracy: 0.9700 - val_loss: 0.1292 - val_accuracy: 0.9433
# Epoch 981/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1077 - accuracy: 0.9671 - val_loss: 0.1258 - val_accuracy: 0.9467
# Epoch 982/1000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1106 - accuracy: 0.9643 - val_loss: 0.1269 - val_accuracy: 0.9467
# Epoch 983/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1071 - accuracy: 0.9657 - val_loss: 0.1285 - val_accuracy: 0.9433
# Epoch 984/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1091 - accuracy: 0.9614 - val_loss: 0.1274 - val_accuracy: 0.9467
# Epoch 985/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1114 - accuracy: 0.9643 - val_loss: 0.1271 - val_accuracy: 0.9467
# Epoch 986/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1065 - accuracy: 0.9657 - val_loss: 0.1474 - val_accuracy: 0.9200
# Epoch 987/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1115 - accuracy: 0.9686 - val_loss: 0.1312 - val_accuracy: 0.9433
# Epoch 988/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1075 - accuracy: 0.9671 - val_loss: 0.1338 - val_accuracy: 0.9467
# Epoch 989/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1080 - accuracy: 0.9686 - val_loss: 0.1291 - val_accuracy: 0.9467
# Epoch 990/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1097 - accuracy: 0.9714 - val_loss: 0.1356 - val_accuracy: 0.9367
# Epoch 991/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1117 - accuracy: 0.9629 - val_loss: 0.1313 - val_accuracy: 0.9400
# Epoch 992/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1058 - accuracy: 0.9657 - val_loss: 0.1306 - val_accuracy: 0.9400
# Epoch 993/1000
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1077 - accuracy: 0.9686 - val_loss: 0.1275 - val_accuracy: 0.9467
# Epoch 994/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1078 - accuracy: 0.9686 - val_loss: 0.1289 - val_accuracy: 0.9433
# Epoch 995/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 0.1127 - accuracy: 0.9686 - val_loss: 0.1269 - val_accuracy: 0.9467
# Epoch 996/1000
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1104 - accuracy: 0.9714 - val_loss: 0.1295 - val_accuracy: 0.9433
# Epoch 997/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1071 - accuracy: 0.9714 - val_loss: 0.1244 - val_accuracy: 0.9500
# Epoch 998/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1063 - accuracy: 0.9657 - val_loss: 0.1326 - val_accuracy: 0.9367
# Epoch 999/1000
# 7/7 [==============================] - 0s 11ms/step - loss: 0.1149 - accuracy: 0.9671 - val_loss: 0.1279 - val_accuracy: 0.9467
# Epoch 1000/1000
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1074 - accuracy: 0.9729 - val_loss: 0.1266 - val_accuracy: 0.9433

# %% [markdown]
# Display predictions and the polynomial curve which was used to separate class instances.

# %%
y_pred = model.predict(X_test)
plt.scatter(X_test[:,0],X_test[:,1],c=y_pred,cmap=cm)
x = np.linspace(0,10,100)
y = (x-1)*(x-6)*(x-7)
plt.plot(x,y,color='g')
# Out:
# 10/10 [==============================] - 0s 2ms/step
